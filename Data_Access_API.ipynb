# %% [markdown]
# <a href="https://colab.research.google.com/github/atenash/data-science-course/blob/main/Data_Access_API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# First of all, we import the required libraries

# %%
import requests
import json
from pprint import pprint

# %% [markdown]
# At this step, we access the data using API

# %%
base_url='https://api.spotify.com/v1/search?q=year:2023&type=album'
headerdic={'Authorization':'Bearer BQCJKo946zU0QEqP-H6PZpDM5i8vuIb83RbJ1iFfJASJqGvolXJ_PdgVXLITZU2zMvzOuMZFtna-CsItFMKREFytBQa1tjzqFMlnZl_d0C0BflKIo3WolIjtLRhAJHFROFbcWj6H6G5eQMPO-kshspBICOGzGPq4wIkv6MY4WHkFt6oStRXnwOETsG9d4QpLk9E'}
resp=requests.get(base_url,headers=headerdic)
print('status_code:',resp.status_code)
# Out:
# status_code: 200

# %% [markdown]
# Saving Data in variable with json format

# %%
data2023=resp.json()
pprint(data2023)
# Out:
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=year%3A2023&type=album&offset=0&limit=20',
#             'items': [{'album_type': 'single',
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4Jd9XCHzRXTB7ZPPVzJoUm'},
#                                     'href': 'https://api.spotify.com/v1/artists/4Jd9XCHzRXTB7ZPPVzJoUm',
#                                     'id': '4Jd9XCHzRXTB7ZPPVzJoUm',
#                                     'name': 'Milano',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4Jd9XCHzRXTB7ZPPVzJoUm'},
#                                    {'external_urls': {'spotify': 'https://open.spotify.com/artist/2Diqn1jFkehRd9MVDGKGdq'},
#                                     'href': 'https://api.spotify.com/v1/artists/2Diqn1jFkehRd9MVDGKGdq',
#                                     'id': '2Diqn1jFkehRd9MVDGKGdq',
# ...

# %% [markdown]
# Save in .json file

# %%
#json. dump() - This method allows you to convert a python object into JSON and additionally allows you to store the information into a file (text file)
json_object=json.dumps(data2023,indent=4)
with open('data2023.json','w') as outfile:
  outfile.write(json_object)

# %% [markdown]
# Filtering Data based on Artist

# %%
base_url='https://api.spotify.com/v1/search?q=artist:Adele &type=album'
headerdic={'Authorization':'Bearer BQCJKo946zU0QEqP-H6PZpDM5i8vuIb83RbJ1iFfJASJqGvolXJ_PdgVXLITZU2zMvzOuMZFtna-CsItFMKREFytBQa1tjzqFMlnZl_d0C0BflKIo3WolIjtLRhAJHFROFbcWj6H6G5eQMPO-kshspBICOGzGPq4wIkv6MY4WHkFt6oStRXnwOETsG9d4QpLk9E'}
resp=requests.get(base_url,headers=headerdic)
print('status_code:',resp.status_code)
Adele2023=resp.json()
pprint(Adele2023)
# Out:
# status_code: 200
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=artist%3AAdele+&type=album&offset=0&limit=20',
#             'items': [{'album_type': 'single',
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/4dpARuHxo51G3z768sgnrY'},
#                                     'href': 'https://api.spotify.com/v1/artists/4dpARuHxo51G3z768sgnrY',
#                                     'id': '4dpARuHxo51G3z768sgnrY',
#                                     'name': 'Adele',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:4dpARuHxo51G3z768sgnrY'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
# ...

# %% [markdown]
# Filtering based on tag:new and limit

# %%
base_url='https://api.spotify.com/v1/search?q=tag:new&type=album&limit=2'
headerdic={'Authorization':'Bearer BQCJKo946zU0QEqP-H6PZpDM5i8vuIb83RbJ1iFfJASJqGvolXJ_PdgVXLITZU2zMvzOuMZFtna-CsItFMKREFytBQa1tjzqFMlnZl_d0C0BflKIo3WolIjtLRhAJHFROFbcWj6H6G5eQMPO-kshspBICOGzGPq4wIkv6MY4WHkFt6oStRXnwOETsG9d4QpLk9E'}
resp=requests.get(base_url,headers=headerdic)
print('status_code:',resp.status_code)
LimitNew=resp.json()
pprint(LimitNew)
# Out:
# status_code: 200
# {'albums': {'href': 'https://api.spotify.com/v1/search?query=tag%3Anew&type=album&offset=0&limit=2',
#             'items': [{'album_type': 'single',
#                        'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/6XyY86QOPPrYVGvF9ch6wz'},
#                                     'href': 'https://api.spotify.com/v1/artists/6XyY86QOPPrYVGvF9ch6wz',
#                                     'id': '6XyY86QOPPrYVGvF9ch6wz',
#                                     'name': 'Linkin Park',
#                                     'type': 'artist',
#                                     'uri': 'spotify:artist:6XyY86QOPPrYVGvF9ch6wz'}],
#                        'available_markets': ['AD',
#                                              'AE',
#                                              'AG',
#                                              'AL',
#                                              'AM',
#                                              'AO',
# ...
